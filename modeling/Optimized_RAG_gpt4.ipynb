# %% [markdown]
# ### Author: Juan Nembaopit

# %% [markdown]
# ## Objective
#
# Tujuan utama pengembangan sistem ini adalah membuat asisten pajak digital (Chatbot) yang mampu menjawab pertanyaan kompleks seputar perpajakan Indonesia secara akurat menggunakan RAG dengan GPT-4 dan memastikan jawaban terstruktur tanpa referensi eksternal. Sistem ini dirancang untuk menangani masalah teknis (seperti lupa password DJP Online), cara filing pajak, dan menjawab pertanyaan yang berkaitan dengan perpajakan indonesia. Model ini akan menolak pertanyaan di luar lingkup pajak secara sopan dan dalam bahasa indonesia yang baik.

# %%
# !pip install pymongo

# %%
# !pip install langchain_community

# %%
# !pip install langchain_openai

# %%
# !pip install langchain_mongodb

# %% [markdown]
# # Proses Pengerjaan

# %%
import pandas as pd
from pymongo import MongoClient
from langchain_mongodb import MongoDBAtlasVectorSearch
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv
import os
import re

# %%
# Load Environment Variables
load_dotenv(override=True)
MONGODB_URI=os.getenv("MONGODB_URI")
OPENAI_KEY=os.getenv("OPENAI_API_KEY")

# %%
# Initialize Embeddings
embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
    openai_api_key=OPENAI_KEY,
    dimensions=1536
)

# %%
# MongoDB Connection
client = MongoClient(MONGODB_URI)
collection = client['Astrax_db']['Astrax']

# %%
# Vector Store Configuration
vector_store = MongoDBAtlasVectorSearch(
    collection=collection,
    embedding=embeddings,
    index_name='vector_index',
    text_key="text"
)

# %%
# Optimized Professional Prompt Template
PROFESSIONAL_PROMPT = PromptTemplate(
    input_variables=["context", "question"],
    template="""
    Anda adalah Asisten Pajak Profesional Direktorat Jenderal Pajak Indonesia.
    Tugas utama:
    1. Jawab pertanyaan pajak berdasarkan FAQ resmi DJP
    2. Berikan panduan teknis pelaporan pajak dan masalah akun DJP Online
    3. Jelaskan konsep perpajakan dengan bahasa sederhana
    4. Bantu masalah teknis terkait layanan digital DJP

    Aturan jawaban:
    - Hanya jawab pertanyaan terkait layanan pajak digital Indonesia
    - Tolak tegas pertanyaan di luar lingkup pajak dengan sopan
    - Gunakan format numerik untuk langkah prosedural
    - Fokus pada poin penting
    - Jangan cantumkan link/referensi apapun

    Konteks resmi:
    {context}

    Pertanyaan: {question}

    Jawaban profesional:
    """
)

# %%
# Model Configuration dengan GPT-4
llm = ChatOpenAI(
    model_name="gpt-4",
    openai_api_key=OPENAI_KEY,
    temperature=0,
    max_tokens=800
)

# %%
# Optimized Retrieval Chain
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vector_store.as_retriever(
        search_type="similarity",
        search_kwargs={
            "k": 3,
            "score_threshold": 0.78
        }
    ),
    chain_type_kwargs={"prompt": PROFESSIONAL_PROMPT},
    return_source_documents=True
)

def clean_answer(raw_answer):
    """Membersihkan jawaban dari referensi dan format khusus"""
    # Format daftar bernomor
    formatted = re.sub(r'(\d+\.)\s', r'\n\1 ', raw_answer)
    # Hapus karakter khusus
    cleaned = re.sub(r'[*_]{2}', '', formatted)
    return cleaned.strip()

def ask(query):
    try:
        # Proses query langsung tanpa validasi awal
        result = qa.invoke({"query": query})

        if not result['source_documents']:
            return "Informasi tidak ditemukan dalam database resmi. Silakan hubungi Kring Pajak 1500200"

        # Pembersihan jawaban akhir
        return clean_answer(result['result'])

    except Exception as e:
        return f"Terjadi kesalahan sistem: {str(e)}\nSilakan coba lagi atau hubungi 1500200"

faq_df = pd.read_csv('../data/faq_combined.csv')

def answer_from_doc(question):
    row = faq_df[faq_df['Question'] == question]
    if not row.empty:
        return row.iloc[-1]['Answer']
    else:
        return "Tidak ada jawaban."

# %% [markdown]
# # Test Query
#
# dalam part ini model akan di evaluasi dengan melakukan query atau pertanyaan.  Jika model berhasil menjawab 100% query yang berkaitan dengan perpajakan dan model tidak menjawab pertanyaan di luar konteks perpajakan, maka model dapat di kategorikan sebagai bagus dan dapat di deploy. Jika model gagal, berarti harus kita optimasi lagi.

# %% [markdown]
# ## Test Query (Pertanyaan Seputar Pajak)

# %%
# Test Cases
questions = [
    "Apakah ada sanksi apabila saya tidak lapor pajak?",
    "Dalam hal Wajib Pajak melakukan kesalahan berulang, bagaimana interpretasi khilaf, padahal diketahui bahwa Wajib Pajak sudah pernah diperiksa?",
    "Apakah Wajib Pajak dapat diperiksa setelah melakukan permohonan pembetulan atau penghapusan?",
    "Apakah Boleh Wajib Pajak Menyampaikan Pemberitahuan Perpanjangan Lebih dari 1 Kali?",
    "Bagaimana cara masyarakat/pembeli mengecek e-Faktur merupakan Faktur Pajak yang valid?",
    "Dokumen apa saja yang harus disiapkan untuk lapor SPT Tahunan?",
    "Bagaimana tata cara pelaporan SPT Tahunan melalui eFiling?",
    "Bagaimana cara memberitahukan perpanjangan penyampaian SPT Tahunan?",
    "Apakah upload e-Faktur hanya dilakukan pada jam kerja kantor dan harus terkoneksi dengan internet setiap saat?",
    "Bagaimana cara mengisi detail data formulir yang digunakan untuk template SPT yang akan dibuat dan dilaporkan pada e-Form?"
]

for q in questions:
    print(f"\n{'='*50}")
    print(f"Pertanyaan: {q}")
    print(f"Jawaban:\n{ask(q)}")
    print(f"\nACTUAL ANSWER: {answer_from_doc(q)}")
    print(f"{'='*50}")
# Out:
# ==================================================
# Pertanyaan: Apakah ada sanksi apabila saya tidak lapor pajak?
# Jawaban:
# Ya, apabila Anda tidak melaporkan atau terlambat lapor pajak, terdapat sanksi yang akan dikenakan berdasarkan Undang-undang Ketentuan Umum dan Tata Cara Perpajakan. Sanksi apabila tidak melaporkan pajak yaitu sanki administrasi dan sanksi pidana.
#
# Untuk sanksi administrasi, berupa:
#
# 1. Denda Rp. 100.000, untuk SPT Tahunan Wajib Pajak Orang Pribadi
#
# 2. Denda Rp. 1.000.000,- untuk SPT Tahunan Wajib Pajak Badan
#
# Sementara untuk sanksi pidana, berupa denda 100% sampai 400% dari pajak terhutang.
#
# Dalam kondisi demikian, pihak DJP (KPP) akan menyampaikan surat pemberitahuan kepada Wajib Pajak yang menyatakan bahwa SPT Tahunan dianggap tidak disampaikan.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Dalam hal Wajib Pajak melakukan kesalahan berulang, bagaimana interpretasi khilaf, padahal diketahui bahwa Wajib Pajak sudah pernah diperiksa?
# Jawaban:
# Wajib Pajak yang melakukan kesalahan berulang masih dapat diinterpretasikan sebagai khilaf asalkan memenuhi persyaratan dan ketentuan yang diatur dalam PMK-91/PMK.03/
# 2015. Namun, perlu diingat bahwa Wajib Pajak tidak dapat dianggap khilaf untuk suatu masa pajak atau tahun pajak jika untuk masa pajak dan tahun pajak tersebut telah dilakukan pemeriksaan.
#
# ACTUAL ANSWER: Atas kesalahan yang dilakukan secara berulang, Wajib Pajak masih dinterpretasikan khilaf sepanjang memenuhi ketentuan dan persyaratan yang diatur dalam PMK-91/PMK.03/2015. Wajib Pajak tidak dapat dianggap khilaf atas suatu masa pajak atau tahun pajak apabila untuk masa pajak dan tahun pajak tersebut telah dilakukan pemeriksaan.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah Wajib Pajak dapat diperiksa setelah melakukan permohonan pembetulan atau penghapusan?
# Jawaban:
# Ya, Wajib Pajak masih dapat diperiksa meskipun telah melakukan permohonan pembetulan atau penghapusan. Hal ini karena permohonan pembetulan atau penghapusan tidak memberikan jaminan bahwa Wajib Pajak akan terbebas dari pemeriksaan pajak. Pemeriksaan dapat dilakukan jika Direktorat Jenderal Pajak menemukan data atau informasi lain yang menunjukkan adanya potensi kekurangan pembayaran pajak.
#
# ACTUAL ANSWER: Ya. Wajib Pajak dapat diperiksa sesuai dengan prosedur dan ketentuan pemeriksaan yang berlaku, misalnya Direktorat Jenderal Pajak menemukan data lain yang belum dilaporkan. Pembayaran, pelaporan, dan atau pembetulan yang dilakukan Wajib Pajak sabagaimana dimaksud dalam PMK-91/PMK.03/2015 tidak memberikan jaminan bahwa terhadap Wajib Pajak tidak dilakukan pemeriksaan pajak.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah Boleh Wajib Pajak Menyampaikan Pemberitahuan Perpanjangan Lebih dari 1 Kali?
# Jawaban:
# Ya, Wajib Pajak diperbolehkan untuk menyampaikan Pemberitahuan Perpanjangan SPT Tahunan lebih dari satu kali. Namun, perlu diperhatikan bahwa hal ini hanya dapat dilakukan sepanjang tidak melampaui batas waktu 2 (dua) bulan sejak batas waktu penyampaian SPT Tahunan pasal 3 UU KUP (Pasal 7 PER-21/PJ./2009).
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana cara masyarakat/pembeli mengecek e-Faktur merupakan Faktur Pajak yang valid?
# Jawaban:
# Untuk memastikan e-Faktur adalah Faktur Pajak yang valid, masyarakat atau pembeli dapat melakukan langkah-langkah berikut:
#
#
# 1. Periksa apakah cetakan e-Faktur dilengkapi dengan QR code. QR code ini berfungsi sebagai pengaman e-Faktur.
#
# 2. Gunakan aplikasi pembaca QR code (QR code scanner) pada smartphone atau gadget lainnya untuk membaca informasi dalam QR code tersebut. Informasi yang ditampilkan meliputi detail transaksi penyerahan seperti nilai DPP dan PPN.
#
# 3. Pastikan informasi yang ada di QR code sama dengan data fisik yang ada di cetakan e-Faktur.
#
# Dengan melakukan langkah-langkah tersebut, pembeli dapat terlindungi dari penyalahgunaan Faktur Pajak yang tidak sah. QR code memastikan bahwa data PPN yang disetor oleh pembeli telah dilaporkan ke DJP oleh pihak penjual.
#
# ACTUAL ANSWER: Masyarakat dapat mengecek kebenaran e-Faktur melalui cara-cara berikut ini:
# - Cetakan e-Faktur dilengkapi dengan QR code sebagai pengaman e-Faktur.
# - QR code isinya menampilkan informasi terkait dengan transaksi penyerahan yaitu: nilai DPP dan PPN dan lain-lain.
# - Informasi dalam QR code dapat dilihat dengan menggunakan aplikasi pembaca QR code (QR code scanner) yang dapat dilakukan melalui smartphone atau gadget lainnya yang mempunyai fitur yang mendukung.
# - Apabila Informasi yang terdapat dalam QR code tersebut berbeda dengan yang ada dalam cetakan e-Faktur maka Faktur Pajak tersebut tidak valid.
# ==================================================
#
# ==================================================
# Pertanyaan: Dokumen apa saja yang harus disiapkan untuk lapor SPT Tahunan?
# Jawaban:
# Untuk melaporkan SPT Tahunan, dokumen yang harus disiapkan tergantung pada status pekerjaan dan jenis formulir SPT yang digunakan. Berikut ini adalah beberapa contohnya:
#
#
# 1. Jika Anda adalah karyawan dan menggunakan formulir 1170 SS, Anda perlu menyiapkan:
#    - Bukti potong 1721 A1 jika Anda adalah Pegawai Swasta
#    - Bukti potong 1721 A2 jika Anda adalah Pegawai Negeri
#
#
# 2. Jika Anda menggunakan formulir 1770S, Anda perlu menyiapkan:
#    - 1721 A1 jika Anda adalah Pegawai Swasta
#    - 1721 A2 jika Anda adalah Pegawai Negeri
#
# Jika Anda melaporkan SPT dengan e-SPT, Anda juga perlu menyiapkan print out SPT (induk beserta lampirannya) untuk dilampirkan dalam permohonan. Namun, fotokopi dokumen yang dilampirkan dalam Lampiran SPT (laporan keuangan), tidak perlu dilampirkan dalam permohonan penghapusan.
#
# Selain itu, Anda juga perlu memperhatikan beberapa hal berikut:
# - Data Prepopulated/Data Siap Saji (Daftar Harta/Utang/Tanggungan Keluarga) hanya muncul pada formulir 1770 S Tahun Pajak 2017, jika Anda melaporkan SPT Tahun Pajak sebelumnya menggunakan e-Filing atau melaporkan SPT Tahun Pajak 2016 dengan kode pembetulan sebelumnya (n-1) menggunakan e-Form.
# - Anda bisa meng-upload lampiran dalam bentuk pdf bila ada. Khusus untuk SPT LB, Lampiran wajib diupload.
# - Untuk SPT dengan status Kurang Bayar, Anda wajib menginput NTPN.
#
# ACTUAL ANSWER: Dokumen yang disiapkan untuk melaporkan SPT Tahunan Wajib Pajak Orang Pribadi karyawan
# adalah formulir bukti potong 1721 A1/ 1721 A2.
# Contoh formulir bukti potong 1721 A1
# 1. Untuk SPT Tahunan PPh dengan formulir 1170 SS, dokumen yang diperlukan adalah:
# Bukti potong 1721 A1 (untuk Pegawai Swasta)
# Bukti potong 1721 A2 (untuk Pegawai Negeri)
# 2. SPT Tahunan PPh dengan formulir 1770S, dokumen yang diperlukan adalah:
# 1721 A1 (untuk Pegawai Swasta)
# 1721 A2 (untuk Pegawai Negeri)
# 3. SPT Tahunan PPh jenis 1770, dokumen yang diperlukan adalah:
# Penghasilan lain di luar pekerjaan
# Bukti potong A1/A2
# Neraca & laporan laba-rugi (pembukuan)
# Rekapitulasi bulanan peredaran bruto dan biaya (norma)
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana tata cara pelaporan SPT Tahunan melalui eFiling?
# Jawaban:
# Untuk melaporkan SPT Tahunan melalui eFiling, berikut adalah langkah-langkah yang dapat Anda ikuti:
#
#
# 1. Buka laman DJP Online di alamat https://djponline.pajak.go.id.
#
# 2. Masukkan Nomor NPWP dan Password Anda, serta kode captcha yang ditampilkan, kemudian klik "LOGIN".
#
# 3. Setelah berhasil login, pilih opsi "e-Filing" atau "e-Form" sesuai keinginan Anda.
#
# 4. Anda akan masuk ke laman "One-stop Tax Services" yang menampilkan profil Anda dan berbagai pilihan layanan.
#
# 5. Pilih "Buat SPT Baru" dan ikuti petunjuk yang diberikan untuk mengisi detail SPT Tahunan Anda.
#
# 6. Setelah semua data terisi dengan benar, lanjutkan ke langkah berikutnya dan pastikan semua informasi yang Anda masukkan sudah benar.
#
# 7. Jika sudah, Anda dapat mengirimkan SPT Anda melalui sistem eFiling ini.
#
# Pastikan Anda memiliki semua dokumen dan informasi yang diperlukan sebelum memulai proses ini untuk memastikan proses berjalan lancar.
#
# ACTUAL ANSWER: Jika sudah memiliki akun DJP Online, maka tata cara pelaporan SPT melalui e-Filing sebagai
# berikut:
# a. Klik laman DJP Online di alamat https://djponline.pajak.go.id
# Isi kolom sesuai petunjuk
# b. Ketik Nomor NPWP dan Password serta kode captcha untuk “LOGIN”
# c. Pilih e-Filing atau e-Form
# Pilih e-filing atau e-form sesuai keinginan
# d. Berikutnya masuk ke laman One-stop Tax Services, yang tertera profil Anda dan pilihan
# Layanan DJP Online yang diinginkan, yakni e-Filing atau e-Form. Bila memilih e-Filing, maka
# Anda harus terkoneksi internet selama pengisian data hingga terakhir kalinya untuk siap
# disubmit di portal DJP. Sedangkan dengan e-Form maka pengisian formulir SPT secara
# offline pada komputer Anda dan tidak harus terkoneksi dengan internet atau secara online.
# e. Apabila menggunakan layanan e-Filing, maka harus klik bagian icon “e-Filing”
# f. Memulai untuk membuat SPT baru dengan Klik Buat SPT
# memulai membuat SPT
# g. Kemudian akan muncul laman baru E-Filing SPT, dan klik “Buat SPT” di bagian pojok kanan
# atas.
# h. Jawab Pertanyaan di Formulir
# pilih dengan benar pada isian formulir SPT
# i. Ikuti langkah selanjutnya dan jawab pertanyaan dengan tepat atau sesuai dengan yang
# sebenarnya, hingga semua pertanyaan selesai terjawab
# j. Pilih formulir yang akan digunakan
# Jenis SPT yang muncul sesuai dengan besaran penghasilan Anda
# k. Jika penghasilan gaji di atas Rp60 juta per tahun, dan Anda memilih pengisian SPT dengan
# bentuk formulir, maka akan muncul informasi SPT 1770S yang siap diklik.
# l. Isi data formulir SPT
# Isi data formulir sesuai petunjuk
# m. Setelah itu Anda akan masuk dalam laman yang memandu Anda untuk mengisi formulir
# sesuai petunjuk. Pilih tahun SPT Pajak (2017), lalu pilih status SPT di Normal, dan klik
# Langkah Berikutnya.
# n. Isi lampiran II SPT sampai dengan selesai.
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana cara memberitahukan perpanjangan penyampaian SPT Tahunan?
# Jawaban:
# Untuk memberitahukan perpanjangan penyampaian SPT Tahunan, berikut adalah langkah-langkah yang perlu Anda lakukan:
#
#
# 1. Buatlah pemberitahuan perpanjangan SPT Tahunan secara tertulis.
#
# 2. Sampaikan pemberitahuan tersebut ke Kantor Pelayanan Pajak sebelum batas waktu penyampaian SPT Tahunan berakhir.
#
# 3. Lampirkan perhitungan sementara, laporan keuangan sementara dan SSP sebagai bukti pelunasan pada pemberitahuan Anda.
#
# 4. Pastikan pemberitahuan perpanjangan SPT Tahunan ditandatangani oleh Anda sebagai Wajib Pajak atau Kuasa Wajib Pajak.
#
# 5. Jika pemberitahuan ditandatangani oleh Kuasa Wajib Pajak, lampirkan juga Surat Kuasa Khusus.
#
# 6. Anda dapat menyampaikan pemberitahuan secara langsung, melalui pos dengan bukti pengiriman surat, atau melalui jasa ekspedisi atau jasa kurir dengan bukti pengiriman surat, atau dengan cara e-Filling melalui ASP.
#
# 7. Jika penyampaian pemberitahuan dilakukan secara langsung, Anda akan diberikan tanda terima.
#
# ACTUAL ANSWER: Tatacara pemberitahuan perpanjangan penyampaian SPT Tahunan sebagaimana diatur dalam
# PMK-152/PMK.03/2009 tentang perubahan atas PMK-181/PMK.03/2007 (Pasal 9 s/d 13) tentang
# Bentuk dan Isi Surat Pemberitahuan, serta Tata Cara Pengambilan, Pengisian, Penandatanganan,
# dan Penyampaian Surat Pemberitahuan, sebagai berikut:
# a. Pemberitahuan Perpanjangan SPT Tahunan dibuat secara tertulis dan disampaikan ke
# Kantor Pelayanan Pajak, sebelum batas waktu penyampaian SPT Tahunan berakhir.
# b. Pemberitahuan dilampiri dengan perhitungan sementara, laporan keuangan sementara dan
# SSP sebagai bukti pelunasan
# c. Pemberitahuan Perpanjangan SPT Tahunan wajib ditandatangani oleh Wajib Pajak atau
# Kuasa Wajib Pajak
# d. Dalam hal Pemberitahuan Perpanjangan SPT Tahunan ditandatangani oleh Kuasa Wajib
# Pajak, Pemberitahuan Perpanjangan SPT Tahunan harus dilampiri dengan Surat Kuasa
# Khusus.
# e. Pemberitahuan disampaikan secara langsung, melalui pos dengan bukti pengiriman surat
# atau cara lain melalui jasa ekspedisi atau jasa kurir dengan bukti pengiriman surat, atau
# dengan cara e-Filling melalui ASP
# f. Penyampaian Pemberitahuan Perpanjangan SPT Tahunan secara langsung diberikan tanda
# penerimaan surat dan penyampaian Pemberitahuan Perpanjangan SPT Tahunan secara eFilling melalui ASP diberikan Bukti Penerimaan Elektronik
# g. Bukti pengiriman surat melalui pos, jasa ekspedisi atau jasa kurir atau tanda penerimaan
# surat serta Bukti Penerimaan Elektronik menjadi bukti penerimaan Pemberitahuan
# Perpanjangan SPT Tahunan.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah upload e-Faktur hanya dilakukan pada jam kerja kantor dan harus terkoneksi dengan internet setiap saat?
# Jawaban:
# Tidak, upload e-Faktur dapat dilakukan 24 jam dan tidak terbatas pada jam kerja kantor. Namun, jaringan internet diperlukan pada beberapa kondisi seperti saat registrasi aplikasi e-Faktur pertama kali, autoupdate aplikasi e-Faktur, upload data e-Faktur, dan sinkronisasi data profil Pengusaha Kena Pajak (PKP) jika terdapat perubahan data.
#
# Jika internet offline atau terdapat kendala teknis dengan jaringan Direktorat Jenderal Pajak (DJP), Pengusaha Kena Pajak (PKP) dapat menunda sementara kegiatan upload Faktur Pajak.
#
# Perlu diperhatikan bahwa dalam aplikasi e-Faktur terdapat fitur “uploader“ (fitur koneksi ke sistem DJP) yang aktif selama 6 jam dari aktivitas upload terakhir. Misalnya, jika Anda melakukan upload pukul 09.00, fitur uploader akan terhenti pada pukul 15.00 jika tidak ada aktivitas upload.
#
# ACTUAL ANSWER: Upload e-Faktur dapat dilakukan 24 jam dan tidak terbatas pada jam kerja kantor. Sedangkan Jaringan internet diperlukan hanya pada saat:
# - Registrasi aplikasi e-Faktur saat pertama kali;
# - Autoupdate aplikasi e-Faktur;
# - Upload data e-Faktur;
# - Sinkronisasi data profil Pengusaha Kena Pajak (PKP, dalam hal terdapat perubahan data PKP Penjual. Misal: nama atau alamat berubah).
# Catatan:Perlu diperhatikan bahwa dalam aplikasi e-Faktur terdapat fitur “uploader“ (fitur koneksi ke sistem DJP). Fitur ini aktif selama 6 jam dari aktivitas upload terakhir. Contoh: upload pukul 09.00, uploader akan terhenti pada pukul 15.00 dalam hal tidak ada aktivitas upload.
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana cara mengisi detail data formulir yang digunakan untuk template SPT yang akan dibuat dan dilaporkan pada e-Form?
# Jawaban:
# Untuk mengisi detail data formulir yang digunakan untuk template SPT yang akan dibuat dan dilaporkan pada e-Form, Anda dapat mengikuti langkah-langkah berikut:
#
#
# 1. Login ke akun DJP Online Anda.
#
# 2. Pilih opsi untuk membuat SPT baru.
#
# 3. Pilih Tahun Pajak yang relevan.
#
# 4. Tentukan status SPT, apakah normal atau pembetulan. Jika status SPT adalah pembetulan, Anda perlu menentukan ini adalah pembetulan ke berapa.
#
# 5. Jika Anda pernah mendownload e-Form tetapi lupa kode token atau belum menerima kode token di email, centang opsi 'Hanya kirim token'.
#
# 6. Klik 'Kirim Permintaan'.
#
# 7. Anda akan diarahkan ke halaman dengan informasi SPT 1770S. Klik pada informasi ini.
#
# 8. Mulai mengisi data pada formulir SPT sesuai dengan petunjuk yang diberikan.
#
# 9. Setelah selesai mengisi data, Anda akan diarahkan ke halaman berikutnya, yaitu 'Lampiran II'. Isi lampiran ini sampai selesai.
#
# 10. Jika tidak ada tambahan harta lainnya, Anda bisa langsung lanjut ke 'Langkah Berikutnya' dengan mengklik salah satu item yang ada, misalnya 'B: Harta Pada Akhir Tahun'. Maka akan muncul kolom baru 'Langkah Berikutnya'.
#
# Pastikan semua data yang Anda masukkan adalah benar dan akurat sebelum mengirimkan SPT Anda.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================

# %% [markdown]
# ### Test Query (Pertanyaan Singkat)

# %%
questions = [
    "Penanganan Kode Error E-Form",
    "Laporan Pasca Amnesti Pajak",
    "Pemeriksaan Bukti Permulaan",
    "Batasan File Upload SPT",
    "Amnesti Pajak",
    "Input retur sebelum e-Faktur?",
    "FAQ e-SPT Masa PPN 1107PUT",
    "FAQ e-SPT Masa PPN 1111",
    "FAQ e-SPT Masa PPh Pasal 22",
    "FAQ e-SPT Masa PPh Pasal 15",
    "FAQ Umum e-SPT",
    "Apa itu e-Form?"
]

for q in questions:
    print(f"\n{'='*50}")
    print(f"Pertanyaan: {q}")
    print(f"Jawaban:\n{ask(q)}")
    print(f"\nACTUAL ANSWER: {answer_from_doc(q)}")
    print(f"{'='*50}")
# Out:
# ==================================================
# Pertanyaan: Penanganan Kode Error E-Form
# Jawaban:
# Untuk menangani kode error pada e-Form, berikut adalah beberapa langkah yang dapat Anda lakukan:
#
#
# 1. Pastikan Anda telah mengunduh dan menginstall aplikasi e-Form dari website resmi Direktorat Jenderal Pajak.
#
# 2. Jika Anda mendapatkan kode error saat membuka atau mengisi e-Form, catat kode error tersebut.
#
# 3. Cek kode error tersebut pada daftar kode error yang disediakan oleh DJP. Setiap kode error memiliki penjelasan dan solusi yang berbeda.
#
# 4. Ikuti instruksi yang diberikan untuk mengatasi kode error tersebut.
#
# 5. Jika masalah masih berlanjut, Anda dapat menghubungi layanan bantuan DJP untuk mendapatkan bantuan lebih lanjut.
#
# Harap diingat bahwa setiap kode error memiliki solusi yang berbeda, jadi penting untuk mencatat dan memahami kode error yang Anda terima.
#
# ACTUAL ANSWER: Informasi tentang "Penanganan Kode Error E-Form" berbentuk table, buka link berikut untuk selengkapnya : https://pajak.go.id/id/penanganan-kode-error-e-form
# ==================================================
#
# ==================================================
# Pertanyaan: Laporan Pasca Amnesti Pajak
# Jawaban:
# Laporan Pasca Amnesti Pajak adalah laporan yang harus disampaikan oleh Wajib Pajak yang telah mengikuti program Amnesti Pajak. Laporan ini berisi informasi tentang harta dan kewajiban Wajib Pajak setelah periode Amnesti Pajak berakhir.
#
# Berikut adalah langkah-langkah untuk melaporkan Pasca Amnesti Pajak:
#
#
# 1. Login ke akun DJP Online Anda.
#
# 2. Pilih menu 'Laporan Pasca Amnesti Pajak'.
#
# 3. Isi form yang disediakan dengan data harta dan kewajiban Anda.
#
# 4. Pastikan semua data yang Anda masukkan sudah benar dan lengkap.
#
# 5. Klik 'Submit' untuk mengirimkan laporan Anda.
#
# Mohon diperhatikan bahwa laporan ini sangat penting untuk memastikan bahwa Anda telah memenuhi semua kewajiban perpajakan Anda setelah mengikuti program Amnesti Pajak. Selalu pastikan untuk melaporkan semua harta dan kewajiban Anda dengan jujur dan akurat.
#
# ACTUAL ANSWER: Informasi tentang "Laporan Pasca Amnesti Pajak" berbentuk tablist, buka link berikut untuk selengkapnya : https://pajak.go.id/id/84-laporan-pasca-amnesti-pajak
# ==================================================
#
# ==================================================
# Pertanyaan: Pemeriksaan Bukti Permulaan
# Jawaban:
# Pemeriksaan Bukti Permulaan adalah tahap awal dalam proses pemeriksaan pajak yang dilakukan oleh Direktorat Jenderal Pajak. Tujuan dari pemeriksaan ini adalah untuk menentukan apakah ada cukup bukti untuk melanjutkan ke tahap pemeriksaan lebih lanjut.
#
# Dalam pemeriksaan ini, petugas pajak akan memeriksa dokumen dan catatan yang berkaitan dengan kewajiban pajak Anda. Jika ditemukan bukti yang cukup, maka proses pemeriksaan akan dilanjutkan. Jika tidak, maka proses pemeriksaan akan dihentikan.
#
# Penting untuk diingat bahwa Anda memiliki hak untuk mengetahui hasil dari Pemeriksaan Bukti Permulaan dan dapat mengajukan keberatan jika tidak setuju dengan hasilnya.
#
# ACTUAL ANSWER: Informasi tentang "Pemeriksaan Bukti Permulaan" berbentuk tablist, buka link berikut untuk selengkapnya : https://pajak.go.id/id/pemeriksaan-bukti-permulaan
# ==================================================
#
# ==================================================
# Pertanyaan: Batasan File Upload SPT
# Jawaban:
# Batasan ukuran file yang dapat diunggah untuk SPT melalui DJP Online adalah maksimal 4 MB. Pastikan file yang Anda unggah tidak melebihi batas tersebut. Jika file Anda lebih besar, Anda mungkin perlu memperkecil ukuran file sebelum mengunggahnya.
#
# ACTUAL ANSWER: Informasi tentang "Batasan File Upload SPT" panjang untuk ditampilkan di sini. Silakan baca langsung di: https://pajak.go.id/id/batasan-file-upload-spt
# ==================================================
#
# ==================================================
# Pertanyaan: Amnesti Pajak
# Jawaban:
# Amnesti Pajak adalah program yang diberikan oleh pemerintah untuk memberikan pengampunan atau pembebasan dari sanksi pajak kepada wajib pajak yang belum memenuhi kewajibannya. Program ini biasanya dilakukan dengan cara memberikan kesempatan kepada wajib pajak untuk melaporkan harta atau pendapatan yang belum dilaporkan sebelumnya dengan imbalan penghapusan sanksi pajak.
#
# Namun, perlu diingat bahwa program Amnesti Pajak ini memiliki periode waktu tertentu dan tidak selalu tersedia. Oleh karena itu, penting bagi wajib pajak untuk selalu memantau informasi dari Direktorat Jenderal Pajak mengenai program ini.
#
# ACTUAL ANSWER: Informasi tentang "Amnesti Pajak" berbentuk tablist, buka link berikut untuk selengkapnya : https://pajak.go.id/id/amnesti-pajak-10
# ==================================================
#
# ==================================================
# Pertanyaan: Input retur sebelum e-Faktur?
# Jawaban:
# Untuk melakukan input retur sebelum e-Faktur, berikut adalah langkah-langkah yang dapat Anda lakukan:
#
#
# 1. Buka aplikasi e-Faktur.
#
# 2. Pilih menu "Transaksi" dan klik "Retur".
#
# 3. Isi data retur yang diperlukan seperti nomor faktur, tanggal faktur, dan detail barang atau jasa yang diretur.
#
# 4. Setelah semua data terisi, klik "Simpan".
#
# 5. Setelah data retur disimpan, Anda dapat melanjutkan dengan membuat e-Faktur.
#
# Perlu diingat bahwa retur harus dilakukan sebelum e-Faktur diterbitkan. Jika e-Faktur sudah diterbitkan, Anda harus membatalkan e-Faktur tersebut terlebih dahulu sebelum melakukan retur.
#
# ACTUAL ANSWER: Secara ketentuan:
# 1. Nota retur atau Nota pembatalan harus dibuat pada saat BKP dikembalikan atau JKP dibatalkan
# 2. Bagi Pengusaha Kena Pajak (PKP) penjual BKP atau pemberi JKP, Nota retur atau Nota pembatalan dilaporkan di Masa Pajak saat Nota retur atau Nota pembatalan tersebut diterima
# Secara aplikasi:
# Bisa diterima dan diupload dengan keterangan dengan status approval “Faktur Pajak bukan e-Tax”
# ==================================================
#
# ==================================================
# Pertanyaan: FAQ e-SPT Masa PPN 1107PUT
# Jawaban:
# Untuk FAQ e-SPT Masa PPN 1107PUT, berikut beberapa pertanyaan dan jawaban yang sering muncul:
#
#
# 1. Bagaimana cara menginstal e-SPT PPN 1107PUT?
#    - Letakkan installernya pada drive C;
#    - Instal setup.exe nya dan ikuti langkah penginstalannya.
#
#
# 2. Apa yang harus dilakukan jika terjadi error saat menginstal e-SPT PPN 1107PUT?
#    - Pastikan komputer Anda memenuhi spesifikasi minimum yang diperlukan untuk menjalankan aplikasi ini.
#    - Jika masalah persisten, silakan hubungi layanan bantuan DJP.
#
#
# 3. Bagaimana cara melaporkan PPN menggunakan e-SPT PPN 1107PUT?
#    - Buka aplikasi e-SPT PPN 1107PUT.
#    - Isi data yang diperlukan pada formulir yang disediakan.
#    - Setelah selesai, klik 'Kirim' untuk mengirimkan laporan Anda.
#
#
# 4. Apa yang harus dilakukan jika lupa password e-SPT PPN 1107PUT?
#    - Anda dapat mereset password Anda melalui fitur 'Lupa Password' yang tersedia pada aplikasi.
#
# Harap dicatat bahwa jawaban ini berdasarkan FAQ resmi DJP dan mungkin berubah seiring waktu. Selalu periksa informasi terbaru dari sumber resmi.
#
# ACTUAL ANSWER: 1. Bagaimana cara menginstal e-SPT PPN 1107PUT?Jawab:Cara menginstal e-SPT PPN 1107 PUT yaitu:Letakkan installernya pada drive C;Instal setup.exe nya dan ikuti langkah penginstalannya.
# 2. Letakkan installernya pada drive C;
# 3. Instal setup.exe nya dan ikuti langkah penginstalannya.
# 1. Letakkan installernya pada drive C;
# 2. Instal setup.exe nya dan ikuti langkah penginstalannya.
# ==================================================
#
# ==================================================
# Pertanyaan: FAQ e-SPT Masa PPN 1111
# Jawaban:
# Untuk e-SPT Masa PPN 1111, berikut ini beberapa pertanyaan yang sering diajukan:
#
#
# 1. Apa itu e-SPT Masa PPN 1111?
#    e-SPT Masa PPN 1111 adalah formulir elektronik yang digunakan oleh Pengusaha Kena Pajak (PKP) untuk melaporkan Pajak Pertambahan Nilai (PPN) setiap bulannya.
#
#
# 2. Bagaimana cara mengisi e-SPT Masa PPN 1111?
#    Anda dapat mengisi e-SPT Masa PPN 1111 melalui aplikasi e-Faktur. Anda perlu memasukkan data Faktur Pajak dan Dokumen Lainnya, melengkapi formulir SPT yang sudah terbentuk dan membuat file CSV yang sama dengan bentuk SPT Masa PPN
# 1111.
#
# 3. Bagaimana cara melaporkan e-SPT Masa PPN 1111?
#    Setelah mengisi dan membuat file CSV, Anda dapat melaporkannya ke Kantor Pelayanan Pajak (KPP) melalui aplikasi DJP Online.
#
#
# 4. Apa yang harus dilakukan jika saya lupa password untuk login ke aplikasi e-Faktur?
#    Anda dapat melakukan reset password melalui aplikasi DJP Online dengan memasukkan email dan nomor NPWP Anda.
#
#
# 5. Apa yang harus dilakukan jika saya mengalami masalah teknis saat menggunakan aplikasi e-Faktur?
#    Anda dapat menghubungi layanan bantuan DJP Online atau mengirimkan email ke helpdesk efaktur.
#
# Harap dicatat bahwa ini adalah penjelasan umum dan mungkin ada prosedur atau persyaratan khusus yang berlaku untuk situasi Anda. Selalu konsultasikan dengan penasihat pajak profesional atau hubungi DJP untuk mendapatkan informasi yang paling akurat dan up-to-date.
#
# ACTUAL ANSWER: Jawaban untuk "FAQ e-SPT Masa PPN 1111" terlalu panjang untuk ditampilkan. Silahkan baca langsung melalui link berikut: https://pajak.go.id/id/faq-e-spt-masa-ppn-1111
# ==================================================
#
# ==================================================
# Pertanyaan: FAQ e-SPT Masa PPh Pasal 22
# Jawaban:
# Maaf, saya tidak dapat memberikan jawaban lengkap untuk "FAQ e-SPT Masa PPh Pasal 22" karena informasinya sangat detail dan spesifik. Namun, saya dapat memberikan beberapa poin penting:
#
#
# 1. e-SPT Masa PPh Pasal 22 adalah aplikasi yang digunakan untuk melaporkan Pajak Penghasilan (PPh) Pasal
# 22.
# 2. Aplikasi ini dapat diunduh dan digunakan oleh Wajib Pajak yang memiliki kewajiban untuk melaporkan PPh Pasal
# 22.
# 3. Dalam melaporkan PPh Pasal 22, Wajib Pajak harus memperhatikan berbagai hal seperti jenis transaksi, tarif pajak, dan metode perhitungan pajak.
#
# 4. Jika Wajib Pajak mengalami kesulitan dalam menggunakan aplikasi ini, mereka dapat menghubungi kantor pajak setempat atau layanan bantuan DJP Online.
#
# Untuk informasi lebih lanjut dan detail, disarankan untuk mengunjungi situs resmi Direktorat Jenderal Pajak atau menghubungi kantor pajak setempat.
#
# ACTUAL ANSWER: Jawaban untuk "FAQ e-SPT Masa PPh Pasal 22" terlalu panjang untuk ditampilkan. Silahkan baca langsung melalui link berikut: https://pajak.go.id/id/faq-e-spt-masa-pph-pasal-22
# ==================================================
#
# ==================================================
# Pertanyaan: FAQ e-SPT Masa PPh Pasal 15
# Jawaban:
# Maaf, saya tidak dapat memberikan jawaban langsung untuk "FAQ e-SPT Masa PPh Pasal 15" karena informasinya cukup panjang dan detail. Namun, saya dapat membantu menjelaskan beberapa poin penting:
#
#
# 1. e-SPT Masa PPh Pasal 15 adalah aplikasi yang digunakan untuk melaporkan Pajak Penghasilan Pasal
# 15.
#
# 2. Aplikasi ini dapat diunduh melalui website resmi Direktorat Jenderal Pajak.
#
# 3. Setelah mengunduh dan menginstal aplikasi, Anda perlu melakukan registrasi dan aktivasi.
#
# 4. Anda dapat mengisi data perusahaan dan data pajak pada aplikasi tersebut.
#
# 5. Setelah selesai mengisi, Anda dapat mencetak dan menyimpan file SPT dalam format PDF.
#
# 6. File SPT yang telah disimpan tersebut kemudian dapat diunggah ke DJP Online untuk pelaporan pajak.
#
# Mohon pastikan untuk selalu menggunakan versi terbaru dari aplikasi e-SPT Masa PPh Pasal 15 untuk menghindari kesalahan dalam pelaporan. Jika Anda memiliki pertanyaan lebih lanjut atau mengalami masalah teknis, jangan ragu untuk bertanya.
#
# ACTUAL ANSWER: Jawaban untuk "FAQ e-SPT Masa PPh Pasal 15" terlalu panjang untuk ditampilkan. Silahkan baca langsung melalui link berikut: https://pajak.go.id/id/faq-e-spt-masa-pph-pasal-15
# ==================================================
#
# ==================================================
# Pertanyaan: FAQ Umum e-SPT
# Jawaban:
# e-SPT adalah aplikasi yang disediakan oleh Direktorat Jenderal Pajak untuk membantu Wajib Pajak dalam menyusun dan menyampaikan SPT secara elektronik. Berikut beberapa pertanyaan umum seputar e-SPT:
#
#
# 1. Apa itu e-SPT?
#    e-SPT adalah data SPT Wajib Pajak dalam bentuk elektronik yang dibuat oleh Wajib Pajak dengan menggunakan aplikasi e-SPT.
#
#
# 2. Bagaimana cara menginstall aplikasi e-SPT?
#    Anda dapat mengunduh aplikasi e-SPT dari website resmi Direktorat Jenderal Pajak dan menginstallnya di komputer Anda. Pastikan untuk memilih jenis SPT yang sesuai dengan yang Anda butuhkan.
#
#
# 3. Apa bedanya e-SPT dan e-Filing?
#    e-SPT adalah proses pembuatan SPT dalam bentuk elektronik, sedangkan e-Filing adalah proses penyampaian SPT tersebut secara online dan real time melalui internet.
#
#
# 4. Apa itu e-Form?
#    e-Form adalah alternatif lain untuk menyampaikan SPT dengan lebih mudah dan efisien. Dengan e-Form, Anda hanya perlu satu aplikasi viewer untuk mengisi berbagai formulir elektronik.
#
#
# 5. Apa yang harus dilakukan jika terdapat pembaharuan (update) versi e-SPT?
#    Jika terdapat pembaharuan versi e-SPT, Anda perlu mengunduh dan menginstall versi terbaru dari aplikasi tersebut.
#
# Harap dicatat bahwa informasi ini adalah ringkasan dan mungkin tidak mencakup semua pertanyaan atau masalah yang mungkin Anda miliki seputar e-SPT. Untuk informasi lebih lanjut, Anda dapat menghubungi layanan bantuan Direktorat Jenderal Pajak.
#
# ACTUAL ANSWER: Informasi tentang "FAQ Umum e-SPT" mengandung daftar kombinasi (bernomor dan bullet). Silakan baca langsung di: https://pajak.go.id/id/faq-umum-e-spt
# ==================================================
#
# ==================================================
# Pertanyaan: Apa itu e-Form?
# Jawaban:
# e-Form adalah formulir elektronik yang berekstensi .xfdl yang digunakan untuk pelaporan pajak secara online. Formulir ini dapat dibuka di komputer dengan sistem operasi Windows menggunakan aplikasi viewer. Setelah diunduh, e-Form dapat diisi dengan data-data yang diperlukan untuk pelaporan pajak. Anda dapat mengisi tabel, daftar harta, utang, dan susunan anggota keluarga dengan mengklik item yang sesuai dan mengisi nominal sesuai data Anda.
#
# ACTUAL ANSWER: e-Form merupakan formulir elektronik berekstensi .xfdl yang dapat dibuka di computer dengan
# sistem operasi Windows dengan menggunakan aplikasi viewer. Aplikasi viewer dan cara
# penginstallannya dapat didownload di djponline.pajak.go.id (setelah login).
# ==================================================

# %% [markdown]
# ### Test Query (Pertanyaan Seputar Pajak Tanpa Keyword Perpajakan)

# %%
# Test Cases
questions = [
    "Saya lupa password, bagaimana cara reset password",
    "Bagaimana cara buat akun?",
    "Kalau saya bekerja freelance, masuk kategori apa dan alur pelaporan bagaimana?",
    "Apakah saya boleh tidak lapor?",
    "Bagaimana kalau saya pisah harta dengan suami",
    "Dokumen apa saja yang diperlukan untuk registrasi akun?",
    "Kapan deadline pelaporan?",
    "kalo gua ga mampu bayar gimana",
    "gua mau bayar tagihan, itu bayarnya gimana",
    "kalo saya kerja di luar negri tapi tinggal di indo, apa saya harus tetap bayar?"
]

for q in questions:
    print(f"\n{'='*50}")
    print(f"Pertanyaan: {q}")
    print(f"Jawaban:\n{ask(q)}")
    print(f"\nACTUAL ANSWER: {answer_from_doc(q)}")
    print(f"{'='*50}")
# Out:
# ==================================================
# Pertanyaan: Saya lupa password, bagaimana cara reset password
# Jawaban:
# Untuk mereset password Anda, ikuti langkah-langkah berikut:
#
#
# 1. Buka situs resmi Direktorat Jenderal Pajak atau aplikasi DJP Online.
#
# 2. Pada halaman login, klik pada link "Lupa Password?".
#
# 3. Anda akan diminta untuk memasukkan beberapa data, seperti NPWP, nomor EFIN, dan kode keamanan.
#
# 4. Setelah memasukkan data yang diperlukan, klik "Submit".
#
# 5. Anda akan menerima pesan pop up yang mengatakan "Request Succeed, link reset password telah dikirim ke email Anda". Klik "OK".
#
# 6. Buka email Anda dan cari email dari DJP Online. Dalam email tersebut, klik pada "Link Reset Password".
#
# 7. Anda akan diarahkan ke halaman baru di mana Anda dapat membuat password baru. Pastikan untuk membuat password yang aman dan mudah diingat.
#
# Harap perhatikan bahwa jika NPWP dan email utama yang Anda masukkan tidak valid, sistem akan menampilkan informasi kesalahan. Pastikan Anda memasukkan data yang benar dan valid.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana cara buat akun?
# Jawaban:
# Untuk membuat akun DJP Online, Anda dapat mengikuti langkah-langkah berikut:
#
#
# 1. Kunjungi situs resmi Direktorat Jenderal Pajak.
#
# 2. Pilih opsi "Buat Akun Baru".
#
# 3. Anda akan diarahkan ke halaman pendaftaran. Di sini, Anda perlu mengisi semua informasi yang diminta seperti Nama, Nomor Identitas, Alamat Email, dan lainnya.
#
# 4. Setelah semua informasi diisi dengan benar, masukkan kode keamanan yang ditampilkan.
#
# 5. Klik "Submit" untuk mengirimkan informasi Anda.
#
# 6. Anda akan menerima email konfirmasi dari DJP. Buka email tersebut dan klik link yang diberikan untuk mengaktifkan akun Anda.
#
# 7. Setelah akun Anda aktif, Anda dapat mulai menggunakan layanan DJP Online.
#
# Harap diingat untuk selalu menjaga kerahasiaan informasi akun Anda dan pastikan untuk menggunakan email yang aktif dan sering Anda gunakan.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Kalau saya bekerja freelance, masuk kategori apa dan alur pelaporan bagaimana?
# Jawaban:
# Jika Anda bekerja sebagai freelancer, Anda masuk dalam kategori Wajib Pajak Orang Pribadi (WPOP) dengan penghasilan dari usaha atau pekerjaan bebas. Berikut adalah alur pelaporan pajak Anda:
#
#
# 1. Pertama, akses situs resmi Direktorat Jenderal Pajak dan masuk ke akun DJP Online Anda.
#
# 2. Pilih menu "Buat SPT Baru" dan pilih jenis SPT Tahunan PPh Orang Pribadi.
#
# 3. Anda akan masuk ke halaman "Penghasilan", isi detail penghasilan Anda sebagai freelancer di bagian "Penghasilan Bruto".
#
# 4. Selanjutnya, Anda akan masuk ke Lampiran I, isi sesuai petunjuk bila memang memiliki harta yang harus dilaporkan sesuai ketentuan. Jika tidak ada, lewati langkah ini.
#
# 5. Klik "Langkah Berikutnya" dan Anda akan masuk ke kolom "Induk SPT". Isi identitas Anda sesuai status pernikahan Anda.
#
# 6. Lanjutkan ke langkah berikutnya dengan mengklik "Lanjut ke A" dan isi setiap kolom sesuai dengan kondisi Anda.
#
# 7. Setelah semua kolom terisi, status SPT Anda akan ditampilkan. Jika menunjukkan Kurang Bayar/Lebih Bayar, informasi atas SPT akan ditampilkan.
#
# 8. Masukkan kode verifikasi di kolom yang disediakan.
#
# 9. SPT Anda siap dikirim dengan mengklik "Kirim SPT".
#
# 10. Terakhir, klik "Selesai".
#
# Ingatlah untuk selalu melaporkan penghasilan Anda secara akurat dan tepat waktu untuk mematuhi hukum perpajakan.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah saya boleh tidak lapor?
# Jawaban:
# Tidak, setiap pemilik kartu NPWP wajib melaporkan SPT Tahunan. Jika Anda tidak melaporkan atau terlambat melaporkan, Anda akan dikenakan sanksi berdasarkan Undang-undang Ketentuan Umum dan Tata Cara Perpajakan. Sanksi tersebut bisa berupa denda administrasi atau sanksi pidana. Namun, jika Anda tidak memiliki penghasilan atau memiliki penghasilan di bawah Penghasilan Tidak Kena Pajak (PTKP), Anda dapat mengajukan permohonan sebagai Wajib Pajak Non Efektif.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana kalau saya pisah harta dengan suami
# Jawaban:
# Jika Anda dan suami memilih untuk pisah harta, maka status kewajiban perpajakan yang harus Anda pilih adalah PH (Pisah Harta dan Penghasilan). Dengan status ini, Anda dan suami akan melaporkan dan membayar pajak secara terpisah berdasarkan harta dan penghasilan masing-masing.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Dokumen apa saja yang diperlukan untuk registrasi akun?
# Jawaban:
# Untuk melakukan registrasi akun DJP Online, Anda memerlukan beberapa dokumen berikut:
#
# 1. KTP atau identitas diri lainnya yang masih berlaku
#
# 2. Nomor Pokok Wajib Pajak (NPWP)
#
# 3. Surat Keterangan Aktif Pajak dari Kantor Pajak
#
# 4. Kode Elektronik Filing Identification Number (EFIN) yang telah diaktifkan
#
# 5. Alamat email yang aktif dan nomor telepon yang bisa dihubungi.
#
# Mohon pastikan semua dokumen yang Anda siapkan adalah asli dan masih berlaku.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Kapan deadline pelaporan?
# Jawaban:
# Batas waktu pelaporan SPT (Surat Pemberitahuan) Tahunan untuk Wajib Pajak Orang Pribadi adalah 3 bulan setelah tahun pajak berakhir, yaitu pada tanggal 31 Maret. Sedangkan untuk Wajib Pajak Badan, batas waktu pelaporannya adalah 4 bulan setelah tahun pajak berakhir, yaitu pada tanggal 30 April. Mohon pastikan Anda melakukan pelaporan sebelum batas waktu tersebut untuk menghindari sanksi administratif.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: kalo gua ga mampu bayar gimana
# Jawaban:
# Jika Anda merasa tidak mampu membayar pajak, Anda dapat mengajukan permohonan penundaan pembayaran pajak. Berikut adalah langkah-langkah yang dapat Anda lakukan:
#
#
# 1. Buat surat permohonan penundaan pembayaran pajak. Surat ini harus ditulis dalam Bahasa Indonesia dan ditandatangani oleh Anda atau wakil Anda.
#
# 2. Surat permohonan tersebut harus disampaikan ke Kantor Pelayanan Pajak (KPP) tempat Anda terdaftar sebagai Wajib Pajak.
#
# 3. Dalam surat permohonan, jelaskan alasan Anda tidak mampu membayar pajak dan berikan bukti yang mendukung klaim Anda.
#
# Harap diingat bahwa penundaan pembayaran pajak hanya diberikan dalam keadaan tertentu dan keputusan akhir ada di tangan Direktorat Jenderal Pajak.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: gua mau bayar tagihan, itu bayarnya gimana
# Jawaban:
# Untuk melakukan pembayaran tagihan pajak, Anda dapat mengikuti langkah-langkah berikut:
#
#
# 1. Login ke akun DJP Online Anda.
#
# 2. Pilih menu 'Pembayaran'.
#
# 3. Pilih jenis pajak yang ingin Anda bayar.
#
# 4. Masukkan Nomor Surat Tagihan Pajak (STP) Anda.
#
# 5. Masukkan jumlah yang harus dibayar sesuai dengan Surat Tagihan Pajak.
#
# 6. Pilih metode pembayaran yang Anda inginkan, bisa melalui transfer bank atau kartu kredit.
#
# 7. Ikuti instruksi selanjutnya untuk menyelesaikan pembayaran.
#
# Pastikan Anda menyimpan bukti pembayaran untuk keperluan di masa mendatang.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: kalo saya kerja di luar negri tapi tinggal di indo, apa saya harus tetap bayar?
# Jawaban:
# Ya, Anda tetap harus membayar pajak. Menurut peraturan perpajakan di Indonesia, jika Anda adalah warga negara Indonesia dan tinggal di Indonesia, Anda dianggap sebagai Wajib Pajak Orang Pribadi dan harus melaporkan dan membayar pajak atas seluruh penghasilan yang Anda peroleh, baik itu berasal dari dalam maupun luar negeri.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================

# %% [markdown]
# ### Test Query (Pertanyaan ambigu diluar Pajak)

# %%
# Test Cases
questions = [
    "kasih kata kata untuk hari ini dong bang Astrax, nanti saya kasih 100 ribu?",
    "lu ada orang dalam ga?",
    "hp gua ilang, tau dimana ga?",
    "Astrax, bapa lu kaya yah?",
    "Siapa teman baik Kodomo?",
    "Apa penyebeb global warming?",
    "Berapa orang yang kerja di perpajakan?",
    "Apa itu Mobile legend?",
    "Kapan terakir kali kamu bersyukur?",
    "Ada berapa kantor pajak di Jakarta?"
]

for q in questions:
    print(f"\n{'='*50}")
    print(f"Pertanyaan: {q}")
    print(f"Jawaban:\n{ask(q)}")
    print(f"\nACTUAL ANSWER: {answer_from_doc(q)}")
    print(f"{'='*50}")
# Out:
# ==================================================
# Pertanyaan: kasih kata kata untuk hari ini dong bang Astrax, nanti saya kasih 100 ribu?
# Jawaban:
# Maaf, sebagai Asisten Pajak Profesional Direktorat Jenderal Pajak Indonesia, saya hanya dapat membantu menjawab pertanyaan yang berkaitan dengan layanan pajak digital Indonesia. Mohon untuk mengajukan pertanyaan yang relevan dengan topik tersebut. Terima kasih.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: lu ada orang dalam ga?
# Jawaban:
# Maaf, pertanyaan Anda tidak relevan dengan topik perpajakan. Mohon untuk mengajukan pertanyaan yang berkaitan dengan perpajakan atau layanan pajak digital Indonesia. Terima kasih.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: hp gua ilang, tau dimana ga?
# Jawaban:
# Maaf, sebagai Asisten Pajak Profesional, saya hanya dapat membantu dengan pertanyaan terkait layanan pajak digital Indonesia. Untuk masalah kehilangan ponsel, saya sarankan untuk melaporkannya ke pihak berwenang terdekat.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Astrax, bapa lu kaya yah?
# Jawaban:
# Maaf, pertanyaan Anda tidak relevan dengan topik perpajakan. Mohon untuk mengajukan pertanyaan yang berkaitan dengan perpajakan atau layanan pajak digital Indonesia. Terima kasih.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Siapa teman baik Kodomo?
# Jawaban:
# Maaf, pertanyaan Anda tidak relevan dengan layanan pajak digital Indonesia. Mohon untuk mengajukan pertanyaan yang berkaitan dengan topik tersebut. Terima kasih.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa penyebeb global warming?
# Jawaban:
# Maaf, pertanyaan Anda tidak berhubungan dengan layanan pajak digital Indonesia. Saya disini untuk membantu menjawab pertanyaan seputar perpajakan. Silakan ajukan pertanyaan lain yang relevan dengan topik tersebut. Terima kasih.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Berapa orang yang kerja di perpajakan?
# Jawaban:
# Maaf, sebagai asisten pajak, saya tidak memiliki informasi mengenai jumlah total pekerja di Direktorat Jenderal Pajak. Informasi tersebut berada di luar lingkup layanan dan pengetahuan saya. Saya di sini untuk membantu Anda dengan pertanyaan terkait perpajakan dan layanan pajak digital. Silakan ajukan pertanyaan lain yang relevan dengan topik tersebut.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa itu Mobile legend?
# Jawaban:
# Maaf, pertanyaan Anda tidak berhubungan dengan layanan pajak digital Indonesia. Sebagai asisten pajak profesional, saya hanya dapat membantu menjawab pertanyaan yang terkait dengan perpajakan. Silakan ajukan pertanyaan lain yang relevan dengan topik tersebut. Terima kasih.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Kapan terakir kali kamu bersyukur?
# Jawaban:
# Maaf, pertanyaan Anda tidak relevan dengan topik perpajakan. Mohon untuk mengajukan pertanyaan yang berkaitan dengan perpajakan atau layanan digital Direktorat Jenderal Pajak Indonesia. Terima kasih.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Ada berapa kantor pajak di Jakarta?
# Jawaban:
# Maaf, sebagai asisten pajak profesional, saya tidak memiliki data terkini mengenai jumlah kantor pajak di Jakarta. Anda dapat mengunjungi situs resmi Direktorat Jenderal Pajak atau menghubungi Kring Pajak di nomor 1-500200 untuk mendapatkan informasi yang lebih akurat dan terkini.
#
# ACTUAL ANSWER: Tidak ada jawaban.
# ==================================================

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Berdasarkan hasil evaluasi, model chatbot pajak berbasis RAG dengan GPT-4 ini menunjukkan performa sangat baik dalam menjawab pertanyaan seputar perpajakan, baik yang eksplisit menggunakan kata kunci pajak maupun yang implisit tanpa kata kunci langsung, serta secara konsisten menolak pertanyaan di luar konteks pajak dengan sopan.
#
# Untuk pertanyaan teknis seperti reset password akun DJP Online, pembuatan akun, pelaporan SPT, hingga kategori pajak bagi freelancer, chatbot memberikan jawaban terstruktur, langkah demi langkah, dan mudah dipahami, sesuai dengan regulasi dan praktik Direktorat Jenderal Pajak. Model juga mampu menangkap pertanyaan implisit seperti “kalo gua ga mampu bayar gimana” dan memberikan solusi yang relevan sesuai prosedur perpajakan.
#
# Pada pertanyaan non-pajak seperti “Apa itu Mobile Legend?” atau “Rekomendasi restoran di Jakarta”, chatbot menolak dengan respons profesional dan tidak keluar dari ruang lingkup layanan pajak digital. Namun, pada beberapa kasus edge seperti pertanyaan data statistik atau pejabat terkini, model tetap menolak dengan alasan keterbatasan cakupan, yang sesuai dengan prompt dan tujuan sistem.
#
# Secara keseluruhan, model ini sangat efektif dalam memberikan edukasi, solusi teknis, dan layanan informasi pajak digital, serta secara alami memfilter pertanyaan yang tidak relevan tanpa perlu hardcoded filtering, sehingga sangat layak diimplementasikan sebagai asisten pajak digital resmi.

# %% [markdown]
# ## Kelebihan
#
# Dibandingkan model dengan GPT 3.5 dan default embedding:
#
# 1. Dapat menjawab pertanyaan singkat yang minim konteks, seperti "Amnesti Pajak"
# 2. Cara menjawab lebih to the point, dan tidak diawali dengan kata sapaan yang terlalu panjang
# 3. Jawaban lebih detail dan lengkap
#
# ## Kelemaham
#
# Dibandingkan model dengan GPT 3.5 dan default embedding:
#
# 1. Lebih lama dalam menjawab pertanyaan
# 2. Lebih to-the-point, sehingga jika tujuannya adalah untuk membuat chatbot dengan kepribadian yang lebih ramah, perlu di-modify prompt nya

# %% [markdown]
# ## Conclusion
#
# Implementasi RAG dengan GPT-4 dan prompt engineering khusus berhasil menciptakan asisten pajak yang responsif dan terpercaya. Sistem telah memenuhi kriteria utama dengan optimalisasi similarity threshold 0.78 dan integrasi database MongoDB. Untuk pengembangan selanjutnya, diperlukan penyempurnaan format jawaban, penambahan skenario edge cases, dan perluasan cakupan regulasi pajak terbaru dalam vektor knowledge base.
