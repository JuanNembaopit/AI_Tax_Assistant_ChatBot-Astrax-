# %%
import pandas as pd

# %%
df = pd.read_csv("../data/hasil_scraping.csv")
df.head()
# Out:
#                                             Question  \
# 0  Penggunaan NPWP 16 Digit pada Aplikasi SAKTI d...
# 1                   PMK-66 Tahun 2023 Terkait Natura
# 2               PMK-72 Tahun 2023 Terkait Amortisasi
# 3             Panduan Pemadanan NPWP Secara Langsung
# 4   Penyampaian SPT Masa  PPh Final dalam Rangka PPS
#
#                                               Answer
# 0  Soal sering ditanya terkait Penggunaan NPWP 16...
# 1  Link PDF: https://pajak.go.id/system/files/202...
# 2  Link PDF: https://pajak.go.id/system/files/202...
# 3  Layanan pemadanan Nomor Pokok Wajib Pajak (NPW...
# 4  Link PDF: https://pajak.go.id/system/files/202...

# %% [markdown]
# The following dataset is taken from https://pajak.go.id/en/node/34236

# %%
df_sph = pd.read_csv("../data/dataset_faq_spt_tahunan.csv")
df_sph
# Out:
#                                              Question  \
# 0       Apa yang dimaksud dengan Surat Pemberitahuan?
# 1   Ada berapa jenis formulir SPT Tahunan bagi Waj...
# 2                  Apa yang dimaksud dengan e-Filing?
# 3                      Apa yang dimaksud dengan EFIN?
# 4   Bagaimana cara mengajukan permohonan untuk mem...
# 5   Apa yang harus dilakukan oleh Wajib Pajak sete...
# 6                  Apakah e-SPT sama dengan e-Filing?
# 7   Bagaimana secara umum skema Penyampaian SPT Ta...
# 8                    Bagaimana cara mengisi e-Filing?
# 9              Mengapa DJP Online tidak bisa diakses?
# 10                Mengapa Kode Keamanan tidak muncul?
# 11  Mengapa saya tidak menerima link aktivasi DJP ...
# 12                     Mengapa NPWP Saya Non Efektif?
# 13  Bagaimana cara mengaktifkan kembali NPWP Non E...
# 14  Bagaimana apabila Saya lupa password untuk log...
# 15    Bagaimana apabila Saya lupa password dan Email?
# ...

# %%
# combine
df_combined = pd.concat([df, df_sph], ignore_index=True)
df_combined.head()
# Out:
#                                             Question  \
# 0  Penggunaan NPWP 16 Digit pada Aplikasi SAKTI d...
# 1                   PMK-66 Tahun 2023 Terkait Natura
# 2               PMK-72 Tahun 2023 Terkait Amortisasi
# 3             Panduan Pemadanan NPWP Secara Langsung
# 4   Penyampaian SPT Masa  PPh Final dalam Rangka PPS
#
#                                               Answer
# 0  Soal sering ditanya terkait Penggunaan NPWP 16...
# 1  Link PDF: https://pajak.go.id/system/files/202...
# 2  Link PDF: https://pajak.go.id/system/files/202...
# 3  Layanan pemadanan Nomor Pokok Wajib Pajak (NPW...
# 4  Link PDF: https://pajak.go.id/system/files/202...

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Question  209 non-null    object
#  1   Answer    209 non-null    object
# dtypes: object(2)
# memory usage: 3.4+ KB

# %%
df_combined.to_csv("../data/faq_combined.csv", index=False)
